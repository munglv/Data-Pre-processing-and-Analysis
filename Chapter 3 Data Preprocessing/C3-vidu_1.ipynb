# %%
import pandas as pd
import glob

# %%
csv_files = glob.glob('data/iris*.csv') # 'data/*.csv'

# %%
csv_files
# Out:
# ['data\\iris_setosa.csv',
#  'data\\iris_versicolor.csv',
#  'data\\iris_virginica.csv']

# %%
lst = []
for fn in csv_files:
    df = pd.read_csv(fn)
    lst.append(df)
data = pd.concat(lst, ignore_index=True)
data
# Out:
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0      1                5.1               3.5                1.4
# 1      2                4.9               3.0                1.4
# 2      3                4.7               3.2                1.3
# 3      4                4.6               3.1                1.5
# 4      5                5.0               3.6                1.4
# ..   ...                ...               ...                ...
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 0                 0.2     Iris-setosa
# 1                 0.2     Iris-setosa
# 2                 0.2     Iris-setosa
# ...
