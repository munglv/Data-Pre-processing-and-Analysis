# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,1,4,5], 'B':[1,2,4,5,6], 'C':[3,4,3,6,7]})
df
# Out:
#    A  B  C
# 0  1  1  3
# 1  2  2  4
# 2  1  4  3
# 3  4  5  6
# 4  5  6  7

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated(subset=['A','C'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
cond = df.duplicated(subset=['A','C'])
cond
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df[cond]
# Out:
#    A  B  C
# 2  1  4  3

# %%
df[~cond]
# Out:
#    A  B  C
# 0  1  1  3
# 1  2  2  4
# 3  4  5  6
# 4  5  6  7

# %%
df
# Out:
#    A  B  C
# 0  1  1  3
# 1  2  2  4
# 2  1  4  3
# 3  4  5  6
# 4  5  6  7

# %%
df.drop_duplicates(subset=['A','C'], keep='first')
# Out:
#    A  B  C
# 0  1  1  3
# 1  2  2  4
# 3  4  5  6
# 4  5  6  7

# %%
df.drop_duplicates(subset=['A','C'], keep='last')
# Out:
#    A  B  C
# 1  2  2  4
# 2  1  4  3
# 3  4  5  6
# 4  5  6  7

# %%
df.drop_duplicates(subset=['A','C'], keep=False)
# Out:
#    A  B  C
# 1  2  2  4
# 3  4  5  6
# 4  5  6  7

# %%
df = pd.DataFrame({'A':[1,2,1,4,5], 'B':[1,2,4,5,6], 'C':[3,4,3,6,7]})
df
# Out:
#    A  B  C
# 0  1  1  3
# 1  2  2  4
# 2  1  4  3
# 3  4  5  6
# 4  5  6  7

# %%
df = df.drop_duplicates(subset=['A','C'], keep='first')

# %%
df
# Out:
#    A  B  C
# 0  1  1  3
# 1  2  2  4
# 3  4  5  6
# 4  5  6  7

# %%
df = pd.DataFrame({'A':[1,2,1,4,5], 'B':[1,2,4,5,6], 'C':[3,4,3,6,7]})
df
# Out:
#    A  B  C
# 0  1  1  3
# 1  2  2  4
# 2  1  4  3
# 3  4  5  6
# 4  5  6  7

# %%
df.drop_duplicates(subset=['A','C'], keep='first', inplace=True)

# %%
df
# Out:
#    A  B  C
# 0  1  1  3
# 1  2  2  4
# 3  4  5  6
# 4  5  6  7
