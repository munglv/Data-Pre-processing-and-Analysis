# %%
import pandas as pd
import numpy as np

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data'
column_names = ['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration', 'num_doors', 'body_style', 
                'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width', 'height', 'curb_weight', 
                'engine_type', 'num_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke', 'compression_ratio', 
                'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price']
automobile_data = pd.read_csv(url, names=column_names, na_values='?')

# %%
automobile_data.dropna(inplace=True)

# %%
X = automobile_data.drop(columns='price')
y = automobile_data['price']

# %%
num_cols = X.select_dtypes(include=['int','float']).columns

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# %%
best_features = SelectKBest(score_func=f_regression, k='all')
best_features.fit(X[num_cols], y);

# %%
df_scores = pd.DataFrame(best_features.scores_)
df_columns = pd.DataFrame(num_cols)

# %%
feature_scores = pd.concat([df_columns, df_scores], axis=1)

# %%
feature_scores.columns = ['Feature', 'Score']

# %%
feature_scores.sort_values(by='Score', ascending=False, inplace=True, ignore_index=True)
feature_scores
# Out:
#               Feature       Score
# 0         curb_weight  622.507422
# 1               width  386.767806
# 2         engine_size  380.882793
# 3              length  215.964328
# 4          horsepower  214.517098
# 5          wheel_base  183.838418
# 6         highway_mpg  169.084529
# 7            city_mpg  144.483602
# 8                bore   62.592369
# 9              height   10.011468
# 10  compression_ratio    7.197125
# 11  normalized_losses    6.731347
# 12           peak_rpm    4.781473
# 13          symboling    4.274082
# 14             stroke    4.160029

# %%
# Thử chọn ra 5 feature có score lớn nhất
# Xem hệ số tương quan Pearson giữa các biến này với nhau, với biến price
# Tạo model và đánh giá
